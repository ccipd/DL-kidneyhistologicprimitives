# %%
# Catherine Jayapandian (cpj3@case.edu)
# Create HDFS Training and Validation Database for Glomerular Tuft segmentation on PAS stained renal biopsy images.

# Useful reference: http://www.andrewjanowczyk.com/pytorch-unet-for-digital-pathology-segmentation/

# %%
dataname="pas-normal-glomerular-tuft-5X"

patch_size=256 #size of the tiles to extract and save in the database, must be >= to training size
stride_size=64 #distance to skip between patches, 1 indicated pixel wise extraction, patch_size would result in non-overlapping tiles
mirror_pad_size=128 # number of pixels to pad *after* resize to image with by mirroring (edge's of patches tend not to be analyzed well, so padding allows them to appear more centered in the patch)
test_set_size=.1 # what percentage of the dataset should be used as a held out validation/testing set
resize=.125 #resize input images (.125*40 = 5X, 0.15*40 = 6X)
classes=[0,1] #what classes we expect to have in the data, here we have only 2 classes but we could add additional classes and/or specify an index from which we would like to ignore

#-----Note---
#One should likely make sure that  (nrow+mirror_pad_size) mod patch_size == 0, where nrow is the number of rows after resizing
#so that no pixels are lost (any remainer is ignored)

# %%
import torch
import tables

import os,sys
import glob

import PIL
import numpy as np

import cv2
import matplotlib.pyplot as plt

from sklearn import model_selection
import sklearn.feature_extraction.image
import random


seed = random.randrange(sys.maxsize) #get a random seed so that we can reproducibly do the cross validation setup
random.seed(seed) # set the seed
print(f"random seed (note down for reproducibility): {seed}")
# Out:
# random seed (note down for reproducibility): 3284356281762107339

# %%
img_dtype = tables.UInt8Atom()  # dtype in which the images will be saved, this indicates that images will be saved as unsigned int 8 bit, i.e., [0,255]
filenameAtom = tables.StringAtom(itemsize=255) #create an atom to store the filename of the image, just incase we need it later,

# %%
files=glob.glob('./training-set/*_tuft_mask.png') # create a list of the files, in this case we're only interested in files which have masks so we can use supervised learning

# %%
# Extract patient id from biopsyid (pid)
pids=list(set(["_".join(os.path.basename(f).split(".")[0].split(" ")[0].split("_")[0:4]) for f in files]))

# %%
#create training and validation stages and split the files appropriately between them
phases={}
phases["train"],phases["val"]=next(iter(model_selection.ShuffleSplit(n_splits=1,test_size=test_set_size).split(pids)))

#specify that we'll be saving 2 different image types to the database, an image and its associated masked
imgtypes=["img","mask"]

# %%
storage={} #holder for future pytables

block_shape={} #block shape specifies what we'll be saving into the pytable array, here we assume that masks are 1d and images are 3d
block_shape["img"]= np.array((patch_size,patch_size,3))
block_shape["mask"]= np.array((patch_size,patch_size)) 

filters=tables.Filters(complevel=6, complib='zlib') #we can also specify filters, such as compression, to improve storage speed


for phase in phases.keys(): #now for each of the phases, we'll loop through the files
    print(phase)
    
    totals=np.zeros((2,len(classes))) # we can to keep counts of all the classes in for in particular training, since we 
    totals[0,:]=classes               # can later use this information to create better weights

    hdf5_file = tables.open_file(f"./{dataname}_{phase}.pytable", mode='w') #open the respective pytable
    storage["filename"] = hdf5_file.create_earray(hdf5_file.root, 'filename', filenameAtom, (0,)) #create the array for storage
    
    for imgtype in imgtypes: #for each of the image types, in this case mask and image, we need to create the associated earray
        storage[imgtype]= hdf5_file.create_earray(hdf5_file.root, imgtype, img_dtype,  
                                                  shape=np.append([0],block_shape[imgtype]), 
                                                  chunkshape=np.append([1],block_shape[imgtype]),
                                                  filters=filters)
    
    for pidi in phases[phase]: #now for each of the files
        pid=pids[pidi]         
        print(pid)
        
        for fname in glob.glob(f'./training-set/{pid}*_tuft_mask.png'): 
            print("filename: ", fname)
            
            for imgtype in imgtypes:
                if(imgtype=="img"): #if we're looking at an img, it must be 3 channel, but cv2 won't load it in the correct channel order, so we need to fix that
                    
                    # images are in the normal glomeruli directory
                    print ("./training-set/"+os.path.basename(fname).replace("_tuft_mask.png",".png"))
                    io=cv2.cvtColor(cv2.imread("./training-set/"+os.path.basename(fname).replace("_tuft_mask.png",".png")),cv2.COLOR_BGR2RGB)
                    interp_method=PIL.Image.BICUBIC
                    
                else: #if its a mask image, then we only need a single channel (since grayscale 3D images are equal in all channels)
                    io=cv2.imread(fname)/255 #the image is loaded as {0,255}, but we'd like to store it as {0,1} since this represents the binary nature of the mask easier
                    interp_method=PIL.Image.NEAREST #want to use nearest! otherwise resizing may cause non-existing classes to be produced via interpolation (e.g., ".25")

                    for i,key in enumerate(classes): #sum the number of pixels, this is done pre-resize, the but proportions don't change which is really what we're after
                        totals[1,i]+=sum(sum(io[:,:,0]==key))
                        
                io = cv2.resize(io,(0,0),fx=resize,fy=resize, interpolation=interp_method) #resize it as specified above
                io = np.pad(io, [(mirror_pad_size, mirror_pad_size), (mirror_pad_size, mirror_pad_size), (0, 0)], mode="reflect")

                #convert input image into overlapping tiles, size is ntiler x ntilec x 1 x patch_size x patch_size x3
                io_arr_out=sklearn.feature_extraction.image.extract_patches(io,(patch_size,patch_size,3),stride_size)
                             
                #resize it into a ntile x patch_size x patch_size x 3
                io_arr_out=io_arr_out.reshape(-1,patch_size,patch_size,3)

                #save the 4D tensor to the table
                if(imgtype=="img"):
                    storage[imgtype].append(io_arr_out)
                else:
                    storage[imgtype].append(io_arr_out[:,:,:,0].squeeze()) #only need 1 channel for mask data

            storage["filename"].append([fname for x in range(io_arr_out.shape[0])]) #add the filename to the storage array
        
    #lastely, we should store the number of pixels
    npixels=hdf5_file.create_carray(hdf5_file.root, 'numpixels', tables.Atom.from_dtype(totals.dtype), totals.shape)
    npixels[:]=totals
    hdf5_file.close()
    print ("done")
# Out:
# train
# 11_26609_028_504
# filename:  ./training-set/11_26609_028_504 L5 PAS (1)_tuft_mask.png
# ./training-set/11_26609_028_504 L5 PAS (1).png
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function extract_patches is deprecated; The function feature_extraction.image.extract_patches has been deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(msg, category=FutureWarning)
# 12_26609_024_502
# filename:  ./training-set/12_26609_024_502 L6 PAS (1)_tuft_mask.png
# ./training-set/12_26609_024_502 L6 PAS (1).png
# 11_26609_033_501
# filename:  ./training-set/11_26609_033_501 LUNK PAS1 (1)_tuft_mask.png
# ./training-set/11_26609_033_501 LUNK PAS1 (1).png
# 12_26609_032_002
# filename:  ./training-set/12_26609_032_002 L02 PAS 1_tuft_mask.png
# ./training-set/12_26609_032_002 L02 PAS 1.png
# 12_26609_029_512
# filename:  ./training-set/12_26609_029_512 L06 PAS 1_tuft_mask.png
# ./training-set/12_26609_029_512 L06 PAS 1.png
# 12_26609_001_011
# filename:  ./training-set/12_26609_001_011 LUNK2 PAS (7)_tuft_mask.png
# ./training-set/12_26609_001_011 LUNK2 PAS (7).png
# filename:  ./training-set/12_26609_001_011 LUNK2 PAS (1)_tuft_mask.png
# ./training-set/12_26609_001_011 LUNK2 PAS (1).png
# filename:  ./training-set/12_26609_001_011 LUNK2 PAS (4)_tuft_mask.png
# ./training-set/12_26609_001_011 LUNK2 PAS (4).png
# 12_26609_027_511
# filename:  ./training-set/12_26609_027_511 L02 PAS 1_tuft_mask.png
# ./training-set/12_26609_027_511 L02 PAS 1.png
# 13_26609_001_505
# filename:  ./training-set/13_26609_001_505 LUNK2 PAS (5)_tuft_mask.png
# ./training-set/13_26609_001_505 LUNK2 PAS (5).png
# filename:  ./training-set/13_26609_001_505 LUNK2 PAS (4)_tuft_mask.png
# ./training-set/13_26609_001_505 LUNK2 PAS (4).png
# filename:  ./training-set/13_26609_001_505 LUNK2 PAS (1)_tuft_mask.png
# ./training-set/13_26609_001_505 LUNK2 PAS (1).png
# 11_26609_023_506
# filename:  ./training-set/11_26609_023_506 L2 PAS (1)_tuft_mask.png
# ./training-set/11_26609_023_506 L2 PAS (1).png
# 12_26609_033_516
# filename:  ./training-set/12_26609_033_516 LUNK PAS 1_tuft_mask.png
# ./training-set/12_26609_033_516 LUNK PAS 1.png
# 11_26609_021_003
# filename:  ./training-set/11_26609_021_003 LUNK PAS (1)_tuft_mask.png
# ./training-set/11_26609_021_003 LUNK PAS (1).png
# filename:  ./training-set/11_26609_021_003 LUNK PAS (8)_tuft_mask.png
# ./training-set/11_26609_021_003 LUNK PAS (8).png
# 11_26609_000_013
# filename:  ./training-set/11_26609_000_013_L04 PAS (2)_tuft_mask.png
# ./training-set/11_26609_000_013_L04 PAS (2).png
# filename:  ./training-set/11_26609_000_013_L04 PAS (1)_tuft_mask.png
# ./training-set/11_26609_000_013_L04 PAS (1).png
# filename:  ./training-set/11_26609_000_013_L04 PAS (3)_tuft_mask.png
# ./training-set/11_26609_000_013_L04 PAS (3).png
# 12_26609_024_019
# filename:  ./training-set/12_26609_024_019 L3 PAS (6)_tuft_mask.png
# ./training-set/12_26609_024_019 L3 PAS (6).png
# filename:  ./training-set/12_26609_024_019 L3 PAS (4)_tuft_mask.png
# ./training-set/12_26609_024_019 L3 PAS (4).png
# 10-26609-024-002
# filename:  ./training-set/10-26609-024-002.L3 PAS (1)_tuft_mask.png
# ./training-set/10-26609-024-002.L3 PAS (1).png
# filename:  ./training-set/10-26609-024-002.L3 PAS 2_tuft_mask.png
# ./training-set/10-26609-024-002.L3 PAS 2.png
# 11_26609_029_601
# filename:  ./training-set/11_26609_029_601 L01 PAS (1)_tuft_mask.png
# ./training-set/11_26609_029_601 L01 PAS (1).png
# 12_26609_096_003
# filename:  ./training-set/12_26609_096_003 L14 PAS (1)_tuft_mask.png
# ./training-set/12_26609_096_003 L14 PAS (1).png
# 11_26609_001_004
# filename:  ./training-set/11_26609_001_004 L8 PAS (1)_tuft_mask.png
# ./training-set/11_26609_001_004 L8 PAS (1).png
# 12_26609_001_502
# filename:  ./training-set/12_26609_001_502 LUNK PAS (1)_tuft_mask.png
# ./training-set/12_26609_001_502 LUNK PAS (1).png
# 12_26609_033_507
# filename:  ./training-set/12_26609_033_507 LUNK PAS 1_tuft_mask.png
# ./training-set/12_26609_033_507 LUNK PAS 1.png
# 12_26609_020_013
# filename:  ./training-set/12_26609_020_013 L08 A1 PAS (1)_tuft_mask.png
# ./training-set/12_26609_020_013 L08 A1 PAS (1).png
# 12_26609_033_515
# filename:  ./training-set/12_26609_033_515 LUNK PAS 1_tuft_mask.png
# ./training-set/12_26609_033_515 LUNK PAS 1.png
# 11_26609_000_505
# filename:  ./training-set/11_26609_000_505_L4_PAS (1)_tuft_mask.png
# ./training-set/11_26609_000_505_L4_PAS (1).png
# filename:  ./training-set/11_26609_000_505_L4_PAS 4_tuft_mask.png
# ./training-set/11_26609_000_505_L4_PAS 4.png
# filename:  ./training-set/11_26609_000_505_L4_PAS 2_tuft_mask.png
# ./training-set/11_26609_000_505_L4_PAS 2.png
# filename:  ./training-set/11_26609_000_505_L4_PAS 3_tuft_mask.png
# ./training-set/11_26609_000_505_L4_PAS 3.png
# 12_26609_21_507
# filename:  ./training-set/12_26609_21_507 L2 PAS 2_tuft_mask.png
# ./training-set/12_26609_21_507 L2 PAS 2.png
# filename:  ./training-set/12_26609_21_507 L2 PAS 3_tuft_mask.png
# ./training-set/12_26609_21_507 L2 PAS 3.png
# filename:  ./training-set/12_26609_21_507 L2 PAS 1_tuft_mask.png
# ./training-set/12_26609_21_507 L2 PAS 1.png
# 12_26609_024_017
# filename:  ./training-set/12_26609_024_017 L3 PAS (2)_tuft_mask.png
# ./training-set/12_26609_024_017 L3 PAS (2).png
# filename:  ./training-set/12_26609_024_017 L3 PAS (1)_tuft_mask.png
# ./training-set/12_26609_024_017 L3 PAS (1).png
# 12_26609_033_509
# filename:  ./training-set/12_26609_033_509 LUNK PAS (1)_tuft_mask.png
# ./training-set/12_26609_033_509 LUNK PAS (1).png
# filename:  ./training-set/12_26609_033_509 LUNK PAS (3)_tuft_mask.png
# ./training-set/12_26609_033_509 LUNK PAS (3).png
# 11_26609_028_508
# filename:  ./training-set/11_26609_028_508 L5 PAS (3)_tuft_mask.png
# ./training-set/11_26609_028_508 L5 PAS (3).png
# filename:  ./training-set/11_26609_028_508 L5 PAS (1)_tuft_mask.png
# ./training-set/11_26609_028_508 L5 PAS (1).png
# 13_26609_026_017
# filename:  ./training-set/13_26609_026_017 L03 PAS 1_tuft_mask.png
# ./training-set/13_26609_026_017 L03 PAS 1.png
# 11_26609_028_507
# filename:  ./training-set/11_26609_028_507  l5 pas (8)_tuft_mask.png
# ./training-set/11_26609_028_507  l5 pas (8).png
# filename:  ./training-set/11_26609_028_507  l5 pas (1)_tuft_mask.png
# ./training-set/11_26609_028_507  l5 pas (1).png
# 12_26609_025_511
# filename:  ./training-set/12_26609_025_511 L02 PAS (3)_tuft_mask.png
# ./training-set/12_26609_025_511 L02 PAS (3).png
# filename:  ./training-set/12_26609_025_511 L02 PAS (1)_tuft_mask.png
# ./training-set/12_26609_025_511 L02 PAS (1).png
# 13_26609_029_103
# filename:  ./training-set/13_26609_029_103 LUNK PAS 1_tuft_mask.png
# ./training-set/13_26609_029_103 LUNK PAS 1.png
# 12_26609_028_514
# filename:  ./training-set/12_26609_028_514 L03 PAS 1_tuft_mask.png
# ./training-set/12_26609_028_514 L03 PAS 1.png
# 10-26609-027-002
# filename:  ./training-set/10-26609-027-002 PAS-5 (3)_tuft_mask.png
# ./training-set/10-26609-027-002 PAS-5 (3).png
# filename:  ./training-set/10-26609-027-002 PAS-5 2_tuft_mask.png
# ./training-set/10-26609-027-002 PAS-5 2.png
# filename:  ./training-set/10-26609-027-002 PAS-5 (4)_tuft_mask.png
# ./training-set/10-26609-027-002 PAS-5 (4).png
# filename:  ./training-set/10-26609-027-002 PAS-5 (1)_tuft_mask.png
# ./training-set/10-26609-027-002 PAS-5 (1).png
# 12_26609_026_504
# filename:  ./training-set/12_26609_026_504 L03 PAS (1)_tuft_mask.png
# ./training-set/12_26609_026_504 L03 PAS (1).png
# 13_26609_029_104
# filename:  ./training-set/13_26609_029_104 L03 PAS 1_tuft_mask.png
# ./training-set/13_26609_029_104 L03 PAS 1.png
# 11_26609_028_509
# filename:  ./training-set/11_26609_028_509 L3 PAS (1)_tuft_mask.png
# ./training-set/11_26609_028_509 L3 PAS (1).png
# 11_26609_000_012
# filename:  ./training-set/11_26609_000_012_L04_PAS (10)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (10).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (6)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (6).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (5)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (5).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (7)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (7).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (11)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (11).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (3)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (3).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (13)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (13).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (8)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (8).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (14)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (14).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (2)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (2).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (1)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (1).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (4)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (4).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (12)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (12).png
# filename:  ./training-set/11_26609_000_012_L04_PAS (9)_tuft_mask.png
# ./training-set/11_26609_000_012_L04_PAS (9).png
# 11_26609_009_012
# filename:  ./training-set/11_26609_009_012 L4 PAS (1)_tuft_mask.png
# ./training-set/11_26609_009_012 L4 PAS (1).png
# 10_26609_028_503
# filename:  ./training-set/10_26609_028_503 L5 PAS (3)_tuft_mask.png
# ./training-set/10_26609_028_503 L5 PAS (3).png
# filename:  ./training-set/10_26609_028_503 L5 PAS (2)_tuft_mask.png
# ./training-set/10_26609_028_503 L5 PAS (2).png
# filename:  ./training-set/10_26609_028_503 L5 PAS (1)_tuft_mask.png
# ./training-set/10_26609_028_503 L5 PAS (1).png
# 11_26609_027_506
# filename:  ./training-set/11_26609_027_506 L05 PAS (1)_tuft_mask.png
# ./training-set/11_26609_027_506 L05 PAS (1).png
# 13_26609_023_518
# filename:  ./training-set/13_26609_023_518 LUNK1 PAS 1_tuft_mask.png
# ./training-set/13_26609_023_518 LUNK1 PAS 1.png
# 11_26609_025_503
# filename:  ./training-set/11_26609_025_503 L2 PAS (2)_tuft_mask.png
# ./training-set/11_26609_025_503 L2 PAS (2).png
# filename:  ./training-set/11_26609_025_503 L2 PAS (1)_tuft_mask.png
# ./training-set/11_26609_025_503 L2 PAS (1).png
# 12_26609_033_511
# filename:  ./training-set/12_26609_033_511 LUNK PAS1 1_tuft_mask.png
# ./training-set/12_26609_033_511 LUNK PAS1 1.png
# 13_26609_028_525
# filename:  ./training-set/13_26609_028_525 L05 PAS (1)_tuft_mask.png
# ./training-set/13_26609_028_525 L05 PAS (1).png
# 11_26609_029_006
# filename:  ./training-set/11_26609_029_006 L3 PAS (1)_tuft_mask.png
# ./training-set/11_26609_029_006 L3 PAS (1).png
# filename:  ./training-set/11_26609_029_006 L3 PAS (3)_tuft_mask.png
# ./training-set/11_26609_029_006 L3 PAS (3).png
# 11_26609_023_510
# filename:  ./training-set/11_26609_023_510 L2 PAS (1)_tuft_mask.png
# ./training-set/11_26609_023_510 L2 PAS (1).png
# 16_26609_022_044
# filename:  ./training-set/16_26609_022_044 L03 PAS (1)_tuft_mask.png
# ./training-set/16_26609_022_044 L03 PAS (1).png
# 12_26609_033_504
# filename:  ./training-set/12_26609_033_504 L02 PAS 1_tuft_mask.png
# ./training-set/12_26609_033_504 L02 PAS 1.png
# 12_26609_028_518
# filename:  ./training-set/12_26609_028_518 L05 PAS 1_tuft_mask.png
# ./training-set/12_26609_028_518 L05 PAS 1.png
# 12_26609_028_513
# filename:  ./training-set/12_26609_028_513 L02 PAS 1_tuft_mask.png
# ./training-set/12_26609_028_513 L02 PAS 1.png
# 11_26609_029_506
# filename:  ./training-set/11_26609_029_506 L1 PAS 1_tuft_mask.png
# ./training-set/11_26609_029_506 L1 PAS 1.png
# filename:  ./training-set/11_26609_029_506 L1 PAS 2_tuft_mask.png
# ./training-set/11_26609_029_506 L1 PAS 2.png
# 11_26609_020_008
# filename:  ./training-set/11_26609_020_008 L08 A1 PAS (1)_tuft_mask.png
# ./training-set/11_26609_020_008 L08 A1 PAS (1).png
# filename:  ./training-set/11_26609_020_008 L08 A1 PAS 1_tuft_mask.png
# ./training-set/11_26609_020_008 L08 A1 PAS 1.png
# filename:  ./training-set/11_26609_020_008 L08 A1 PAS 2_tuft_mask.png
# ./training-set/11_26609_020_008 L08 A1 PAS 2.png
# 12_26609_027_018
# filename:  ./training-set/12_26609_027_018 L10 PAS (1)_tuft_mask.png
# ./training-set/12_26609_027_018 L10 PAS (1).png
# 11_26609_026_008
# filename:  ./training-set/11_26609_026_008 L03 PAS (2)_tuft_mask.png
# ./training-set/11_26609_026_008 L03 PAS (2).png
# filename:  ./training-set/11_26609_026_008 L03 PAS (1)_tuft_mask.png
# ./training-set/11_26609_026_008 L03 PAS (1).png
# 12-26609-027-015
# filename:  ./training-set/12-26609-027-015 L02 PAS 1_tuft_mask.png
# ./training-set/12-26609-027-015 L02 PAS 1.png
# filename:  ./training-set/12-26609-027-015 L02 PAS 2_tuft_mask.png
# ./training-set/12-26609-027-015 L02 PAS 2.png
# 12_26609_033_514
# filename:  ./training-set/12_26609_033_514 LUNK PAS 1_tuft_mask.png
# ./training-set/12_26609_033_514 LUNK PAS 1.png
# 13_26609_027_521
# filename:  ./training-set/13_26609_027_521  L01  PAS 1_tuft_mask.png
# ./training-set/13_26609_027_521  L01  PAS 1.png
# 12_26609_027_513
# filename:  ./training-set/12_26609_027_513_FR_L2_PAS 1_tuft_mask.png
# ./training-set/12_26609_027_513_FR_L2_PAS 1.png
# 11_26609_023_507
# filename:  ./training-set/11_26609_023_507 L2 PAS (1)_tuft_mask.png
# ./training-set/11_26609_023_507 L2 PAS (1).png
# 13_26609_029_514
# filename:  ./training-set/13_26609_029_514 L01 PAS 1_tuft_mask.png
# ./training-set/13_26609_029_514 L01 PAS 1.png
# 10_26609_023_502
# filename:  ./training-set/10_26609_023_502 L9 PAS 1_tuft_mask.png
# ./training-set/10_26609_023_502 L9 PAS 1.png
# filename:  ./training-set/10_26609_023_502 L9 PAS 2_tuft_mask.png
# ./training-set/10_26609_023_502 L9 PAS 2.png
# 11_26609_000_502
# filename:  ./training-set/11_26609_000_502_L4_PAS (4)_tuft_mask.png
# ./training-set/11_26609_000_502_L4_PAS (4).png
# filename:  ./training-set/11_26609_000_502_L4_PAS (1)_tuft_mask.png
# ./training-set/11_26609_000_502_L4_PAS (1).png
# filename:  ./training-set/11_26609_000_502_L4_PAS (3)_tuft_mask.png
# ./training-set/11_26609_000_502_L4_PAS (3).png
# 12_26609_026_508
# filename:  ./training-set/12_26609_026_508 L03 PAS (1)_tuft_mask.png
# ./training-set/12_26609_026_508 L03 PAS (1).png
# filename:  ./training-set/12_26609_026_508 L03 PAS (4)_tuft_mask.png
# ./training-set/12_26609_026_508 L03 PAS (4).png
# 10_26609_028_502
# filename:  ./training-set/10_26609_028_502 L5 PAS 7_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 7.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 1_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 1.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 9_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 9.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 5_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 5.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 10_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 10.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 8_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 8.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 6_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 6.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 3_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 3.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 4_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 4.png
# filename:  ./training-set/10_26609_028_502 L5 PAS 2_tuft_mask.png
# ./training-set/10_26609_028_502 L5 PAS 2.png
# 11_26609_026_503
# filename:  ./training-set/11_26609_026_503_L3 PAS (1)_tuft_mask.png
# ./training-set/11_26609_026_503_L3 PAS (1).png
# filename:  ./training-set/11_26609_026_503_L3 PAS (5)_tuft_mask.png
# ./training-set/11_26609_026_503_L3 PAS (5).png
# 12_26609_029_509
# filename:  ./training-set/12_26609_029_509 L11 PAS 1_tuft_mask.png
# ./training-set/12_26609_029_509 L11 PAS 1.png
# 11_26609_025_507
# filename:  ./training-set/11_26609_025_507 L2 PAS (4)_tuft_mask.png
# ./training-set/11_26609_025_507 L2 PAS (4).png
# filename:  ./training-set/11_26609_025_507 L2 PAS (2)_tuft_mask.png
# ./training-set/11_26609_025_507 L2 PAS (2).png
# filename:  ./training-set/11_26609_025_507 L2 PAS (3)_tuft_mask.png
# ./training-set/11_26609_025_507 L2 PAS (3).png
# filename:  ./training-set/11_26609_025_507 L2 PAS (5)_tuft_mask.png
# ./training-set/11_26609_025_507 L2 PAS (5).png
# filename:  ./training-set/11_26609_025_507 L2 PAS (6)_tuft_mask.png
# ./training-set/11_26609_025_507 L2 PAS (6).png
# filename:  ./training-set/11_26609_025_507 L2 PAS (7)_tuft_mask.png
# ./training-set/11_26609_025_507 L2 PAS (7).png
# 12_26609_033_512
# filename:  ./training-set/12_26609_033_512 LUNK PAS1 1_tuft_mask.png
# ./training-set/12_26609_033_512 LUNK PAS1 1.png
# 12_26609_025_510
# filename:  ./training-set/12_26609_025_510 L02 PAS (1)_tuft_mask.png
# ./training-set/12_26609_025_510 L02 PAS (1).png
# 12_26609_028_012
# filename:  ./training-set/12_26609_028_012 L02 PAS 1_tuft_mask.png
# ./training-set/12_26609_028_012 L02 PAS 1.png
# 13_26609_027_025
# filename:  ./training-set/13_26609_027_025  L02 PAS 1_tuft_mask.png
# ./training-set/13_26609_027_025  L02 PAS 1.png
# 12_26609_026_505
# filename:  ./training-set/12_26609_026_505 L03 PAS (1)_tuft_mask.png
# ./training-set/12_26609_026_505 L03 PAS (1).png
# 11_26609_000_503
# filename:  ./training-set/11_26609_000_503_L4_PAS (5)_tuft_mask.png
# ./training-set/11_26609_000_503_L4_PAS (5).png
# filename:  ./training-set/11_26609_000_503_L4_PAS (1)_tuft_mask.png
# ./training-set/11_26609_000_503_L4_PAS (1).png
# filename:  ./training-set/11_26609_000_503_L4_PAS (3)_tuft_mask.png
# ./training-set/11_26609_000_503_L4_PAS (3).png
# filename:  ./training-set/11_26609_000_503_L4_PAS (4)_tuft_mask.png
# ./training-set/11_26609_000_503_L4_PAS (4).png
# filename:  ./training-set/11_26609_000_503_L4_PAS (2)_tuft_mask.png
# ./training-set/11_26609_000_503_L4_PAS (2).png
# filename:  ./training-set/11_26609_000_503_L4_PAS (12)_tuft_mask.png
# ./training-set/11_26609_000_503_L4_PAS (12).png
# 12_26609_099_008
# filename:  ./training-set/12_26609_099_008 L04 PAS (1)_tuft_mask.png
# ./training-set/12_26609_099_008 L04 PAS (1).png
# filename:  ./training-set/12_26609_099_008 L04 PAS (2)_tuft_mask.png
# ./training-set/12_26609_099_008 L04 PAS (2).png
# 13_26609_022_024
# filename:  ./training-set/13_26609_022_024 L03 PAS (1)_tuft_mask.png
# ./training-set/13_26609_022_024 L03 PAS (1).png
# 12_26609_029_507
# filename:  ./training-set/12_26609_029_507 L6 PAS 1_tuft_mask.png
# ./training-set/12_26609_029_507 L6 PAS 1.png
# 12_26609_033_517
# filename:  ./training-set/12_26609_033_517 LUNK PAS 1_tuft_mask.png
# ./training-set/12_26609_033_517 LUNK PAS 1.png
# 13_26609_024_025
# filename:  ./training-set/13_26609_024_025 L03 PAS 1_tuft_mask.png
# ./training-set/13_26609_024_025 L03 PAS 1.png
# 10_26609_028_501
# filename:  ./training-set/10_26609_028_501  L5 PAS (7)_tuft_mask.png
# ./training-set/10_26609_028_501  L5 PAS (7).png
# filename:  ./training-set/10_26609_028_501  L5 PAS (3)_tuft_mask.png
# ./training-set/10_26609_028_501  L5 PAS (3).png
# filename:  ./training-set/10_26609_028_501  L5 PAS (6)_tuft_mask.png
# ./training-set/10_26609_028_501  L5 PAS (6).png
# filename:  ./training-set/10_26609_028_501  L5 PAS (5)_tuft_mask.png
# ./training-set/10_26609_028_501  L5 PAS (5).png
# filename:  ./training-set/10_26609_028_501  L5 PAS (4)_tuft_mask.png
# ./training-set/10_26609_028_501  L5 PAS (4).png
# filename:  ./training-set/10_26609_028_501  L5 PAS (1)_tuft_mask.png
# ./training-set/10_26609_028_501  L5 PAS (1).png
# filename:  ./training-set/10_26609_028_501  L5 PAS (2)_tuft_mask.png
# ./training-set/10_26609_028_501  L5 PAS (2).png
# 13_26609_007_001
# filename:  ./training-set/13_26609_007_001 L11 PAS (1)_tuft_mask.png
# ./training-set/13_26609_007_001 L11 PAS (1).png
# 11_26609_098_003
# filename:  ./training-set/11_26609_098_003_LPAS (1)_tuft_mask.png
# ./training-set/11_26609_098_003_LPAS (1).png
# done
# val
# 11_26609_027_503
# filename:  ./training-set/11_26609_027_503 L02 PAS (2)_tuft_mask.png
# ./training-set/11_26609_027_503 L02 PAS (2).png
# filename:  ./training-set/11_26609_027_503 L02 PAS (1)_tuft_mask.png
# ./training-set/11_26609_027_503 L02 PAS (1).png
# filename:  ./training-set/11_26609_027_503 L02 PAS (4)_tuft_mask.png
# ./training-set/11_26609_027_503 L02 PAS (4).png
# 11_26609_027_509
# filename:  ./training-set/11_26609_027_509_L2_PAS (1)_tuft_mask.png
# ./training-set/11_26609_027_509_L2_PAS (1).png
# filename:  ./training-set/11_26609_027_509_L5_PAS (1)_tuft_mask.png
# ./training-set/11_26609_027_509_L5_PAS (1).png
# filename:  ./training-set/11_26609_027_509_L5_PAS (2)_tuft_mask.png
# ./training-set/11_26609_027_509_L5_PAS (2).png
# 12_26609_025_509
# filename:  ./training-set/12_26609_025_509 L02 PAS (1)_tuft_mask.png
# ./training-set/12_26609_025_509 L02 PAS (1).png
# 13_26609_001_013
# filename:  ./training-set/13_26609_001_013 LUNK2 PAS 1_tuft_mask.png
# ./training-set/13_26609_001_013 LUNK2 PAS 1.png
# 10_26609_025_501
# filename:  ./training-set/10_26609_025_501 L2 PAS 9_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 9.png
# filename:  ./training-set/10_26609_025_501 L2 PAS 4_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 4.png
# filename:  ./training-set/10_26609_025_501 L2 PAS 2_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 2.png
# filename:  ./training-set/10_26609_025_501 L2 PAS 5_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 5.png
# filename:  ./training-set/10_26609_025_501 L2 PAS 6_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 6.png
# filename:  ./training-set/10_26609_025_501 L2 PAS 8_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 8.png
# filename:  ./training-set/10_26609_025_501 L2 PAS 1_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 1.png
# filename:  ./training-set/10_26609_025_501 L2 PAS 3_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 3.png
# filename:  ./training-set/10_26609_025_501 L2 PAS 7_tuft_mask.png
# ./training-set/10_26609_025_501 L2 PAS 7.png
# 12_26609_029_511
# filename:  ./training-set/12_26609_029_511 L11 PAS 1_tuft_mask.png
# ./training-set/12_26609_029_511 L11 PAS 1.png
# 12_26609_029_508
# filename:  ./training-set/12_26609_029_508 L01 PAS (6)_tuft_mask.png
# ./training-set/12_26609_029_508 L01 PAS (6).png
# filename:  ./training-set/12_26609_029_508 L01 PAS (1)_tuft_mask.png
# ./training-set/12_26609_029_508 L01 PAS (1).png
# 12_26609_096_002
# filename:  ./training-set/12_26609_096_002 L5 PAS 1_tuft_mask.png
# ./training-set/12_26609_096_002 L5 PAS 1.png
# 13_26609_028_524
# filename:  ./training-set/13_26609_028_524 L05 PAS 1_tuft_mask.png
# ./training-set/13_26609_028_524 L05 PAS 1.png
# done

# %% [markdown]
# useful reference
# http://machinelearninguru.com/deep_learning/data_preparation/hdf5/hdf5.html
